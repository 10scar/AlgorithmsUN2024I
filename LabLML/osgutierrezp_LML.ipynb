# %% [markdown]
# <a href="https://colab.research.google.com/github/10scar/AlgorithmsUN2024I/blob/main/LabLML/osgutierrezp_LML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning to find the máximum with a Neural Network (MLPRegressor)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
  list1 = list(range(n))
  rnd.shuffle(list1)
  X.append(np.array(list1))
  max_ = max(list1)
  y.append(np.array(max_))

# %%
import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y]})
data
# Out:
#                                   X  y
# 0    [1, 2, 4, 3, 9, 8, 0, 5, 7, 6]  9
# 1    [4, 3, 1, 7, 8, 0, 6, 9, 5, 2]  9
# 2    [5, 7, 3, 4, 2, 9, 6, 0, 1, 8]  9
# 3    [1, 7, 8, 0, 9, 3, 4, 5, 2, 6]  9
# 4    [2, 6, 5, 0, 7, 4, 3, 8, 1, 9]  9
# ..                              ... ..
# 995  [2, 4, 9, 1, 6, 7, 5, 3, 8, 0]  9
# 996  [3, 1, 5, 7, 2, 4, 8, 0, 6, 9]  9
# 997  [2, 6, 5, 4, 1, 0, 8, 3, 7, 9]  9
# 998  [5, 3, 6, 4, 7, 2, 9, 1, 8, 0]  9
# 999  [9, 8, 0, 6, 2, 7, 5, 3, 1, 4]  9
#
# [1000 rows x 2 columns]

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(100,50,20),random_state=1, max_iter=1000, activation='logistic').fit(X,y)
y_pred =model.predict(X)

import matplotlib.pyplot as plt
plt.plot(model.loss_curve_)
plt.show()

# %%
import pandas as pd
y_p = pd.DataFrame({'y_pred':[ round(pred,3) for pred in y_pred]})
y_p
# Out:
#      y_pred
# 0      8.96
# 1      8.96
# 2      8.96
# 3      8.96
# 4      8.96
# ..      ...
# 995    8.96
# 996    8.96
# 997    8.96
# 998    8.96
# 999    8.96
#
# [1000 rows x 1 columns]

# %%
import random as rnd
import numpy as np
import pandas as pd

# Parámetros
n = 10
Nexamples = 1000


X = []
y = []
for j in range(Nexamples):
    list1 = list(2 * np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

y_pred = model.predict(X)
data = pd.DataFrame({
    'X': [a for a in X],
    'y': [a for a in y],
    'y_pred': [int(round(pred)) for pred in y_pred],
    'y_pred_rounded': y_pred
})

data.head()
# Out:
#                                      X   y  y_pred  y_pred_rounded
# 0  [2, 10, 6, 8, 12, 18, 14, 0, 16, 4]  18       9        8.960210
# 1  [0, 4, 6, 18, 8, 2, 14, 12, 10, 16]  18       9        8.960213
# 2  [14, 2, 12, 16, 4, 8, 18, 6, 0, 10]  18       9        8.960209
# 3  [0, 16, 10, 6, 14, 2, 4, 12, 8, 18]  18       9        8.960196
# 4  [8, 12, 10, 6, 4, 16, 14, 18, 0, 2]  18       9        8.960208

# %% [markdown]
# FALTA ENTRENAR CON MÁS DATOS DIFERENTES

# %%
import random as rnd
import numpy as np
import pandas as pd

# Parámetros
n = 10
Nexamples = 10000


X = []
y = []
for j in range(Nexamples):
    list1 = list(2 * np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

y_pred = model.predict(X)
data = pd.DataFrame({
    'X': [a for a in X],
    'y': [a for a in y],
    'y_pred': [int(round(pred)) for pred in y_pred],
    'y_pred_rounded': y_pred
})

data.head()
# Out:
#                                      X   y  y_pred  y_pred_rounded
# 0  [18, 14, 12, 8, 6, 16, 4, 2, 10, 0]  18      18       17.998866
# 1  [10, 18, 16, 12, 14, 0, 8, 4, 6, 2]  18      18       17.998863
# 2  [2, 16, 4, 0, 10, 18, 8, 12, 14, 6]  18      18       17.998865
# 3  [0, 16, 8, 10, 14, 4, 12, 2, 6, 18]  18      18       17.998862
# 4  [8, 14, 6, 18, 2, 10, 4, 16, 0, 12]  18      18       17.998863

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='tanh').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [0, 5, 1, 7, 6, 8, 4, 9, 3, 2]   9       9
# 1          [4, 7, 3, 2, 9, 0, 5, 1, 8, 6]   9       9
# 2          [9, 6, 0, 7, 4, 3, 5, 1, 2, 8]   9       9
# 3          [6, 3, 2, 1, 7, 8, 0, 9, 5, 4]   9       9
# 4          [0, 1, 6, 4, 8, 9, 2, 3, 5, 7]   9       9
# ...                                   ...  ..     ...
# 1995  [4, 12, 6, 0, 2, 18, 8, 10, 14, 16]  18      18
# 1996  [8, 2, 12, 0, 4, 6, 10, 18, 16, 14]  18      18
# 1997  [2, 10, 0, 16, 6, 18, 14, 8, 12, 4]  18      18
# 1998  [14, 4, 2, 8, 12, 16, 0, 18, 6, 10]  18      18
# 1999  [14, 10, 8, 18, 16, 2, 0, 4, 6, 12]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='relu').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [8, 5, 6, 1, 7, 0, 3, 2, 9, 4]   9       9
# 1          [1, 7, 4, 5, 6, 8, 2, 3, 9, 0]   9       9
# 2          [5, 7, 6, 0, 1, 2, 3, 9, 8, 4]   9       9
# 3          [4, 6, 8, 9, 5, 7, 2, 3, 1, 0]   9       9
# 4          [6, 3, 1, 2, 4, 8, 0, 7, 5, 9]   9       9
# ...                                   ...  ..     ...
# 1995  [14, 16, 2, 6, 12, 18, 0, 4, 10, 8]  18      18
# 1996  [6, 8, 2, 10, 18, 12, 0, 4, 16, 14]  18      18
# 1997  [16, 10, 6, 0, 14, 2, 4, 18, 8, 12]  18      18
# 1998  [18, 6, 14, 16, 4, 2, 12, 0, 10, 8]  18      18
# 1999  [8, 12, 4, 16, 14, 10, 18, 0, 6, 2]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                          X   y  y_pred
# 0           [6, 2, 7, 4, 5, 0, 3, 8, 9, 1]   9       9
# 1           [8, 0, 7, 9, 3, 2, 4, 5, 1, 6]   9       9
# 2           [7, 4, 5, 6, 3, 2, 1, 0, 8, 9]   9       9
# 3           [3, 5, 8, 7, 4, 9, 1, 6, 2, 0]   9       9
# 4           [2, 1, 9, 0, 7, 5, 6, 4, 3, 8]   9       9
# ...                                    ...  ..     ...
# 19995  [10, 0, 2, 6, 16, 8, 12, 14, 18, 4]  18      18
# 19996  [12, 6, 8, 14, 10, 0, 16, 4, 2, 18]  18      18
# 19997  [8, 4, 16, 2, 12, 6, 14, 10, 0, 18]  18      18
# 19998  [2, 10, 0, 18, 4, 8, 16, 6, 12, 14]  18      18
# 19999  [4, 2, 14, 10, 18, 12, 16, 0, 6, 8]  18      18
#
# [20000 rows x 3 columns]

# %% [markdown]
# # Learning to to find the máximum with a Classification and Regression Tree (CART)
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85
#
# * https://spotle.ai/feeddetails/Classification-and-Regression-Tree-CART-with-Python/3644
#
# ### Visualize a Decision Tree in 4 Ways with Scikit-Learn and Python
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

model = DecisionTreeRegressor(max_leaf_nodes = 15).fit(X,y)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))



y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
#                                    X  y  y_pred
# 0     [4, 9, 1, 8, 7, 2, 0, 3, 5, 6]  9       9
# 1     [0, 1, 3, 8, 6, 2, 7, 9, 4, 5]  9       9
# 2     [7, 2, 1, 9, 8, 4, 3, 5, 0, 6]  9       9
# 3     [0, 9, 3, 2, 4, 8, 6, 1, 5, 7]  9       9
# 4     [8, 7, 0, 1, 2, 3, 9, 6, 5, 4]  9       9
# ...                              ... ..     ...
# 9995  [1, 0, 2, 4, 7, 5, 6, 3, 9, 8]  9       9
# 9996  [9, 4, 2, 8, 0, 6, 7, 3, 5, 1]  9       9
# 9997  [5, 1, 3, 2, 7, 4, 6, 0, 9, 8]  9       9
# 9998  [1, 4, 5, 8, 7, 0, 3, 9, 2, 6]  9       9
# 9999  [6, 9, 3, 0, 1, 7, 4, 2, 8, 5]  9       9
#
# [10000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- value: [9.00]

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.992
#                                          X   y  y_pred
# 0           [5, 0, 2, 3, 7, 1, 6, 8, 9, 4]   9       9
# 1           [2, 5, 1, 3, 0, 9, 8, 6, 7, 4]   9       9
# 2           [7, 9, 8, 1, 6, 3, 2, 5, 0, 4]   9       9
# 3           [4, 1, 9, 6, 2, 8, 5, 3, 0, 7]   9       9
# 4           [8, 7, 0, 1, 5, 4, 9, 2, 3, 6]   9       9
# ...                                    ...  ..     ...
# 19995  [8, 0, 4, 14, 10, 12, 2, 6, 16, 18]  18      18
# 19996  [4, 14, 6, 2, 12, 16, 10, 8, 0, 18]  18      18
# 19997  [16, 14, 4, 12, 6, 2, 10, 8, 0, 18]  18      18
# 19998  [0, 16, 18, 12, 8, 10, 14, 6, 4, 2]  18      18
# 19999  [6, 12, 18, 10, 2, 8, 14, 0, 16, 4]  18      18
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_5 <= 9.50
# |   |--- feature_4 <= 9.50
# |   |   |--- feature_9 <= 9.50
# |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |--- feature_2 <= 9.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- feature_2 >  9.50
# |   |   |   |   |   |--- value: [18.00]
# |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |--- value: [18.00]
# |   |   |--- feature_9 >  9.50
# |   |   |   |--- value: [18.00]
# |   |--- feature_4 >  9.50
# |   |   |--- value: [18.00]
# |--- feature_5 >  9.50
# |   |--- value: [18.00]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()

# %% [markdown]
# Random Test

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = rnd.sample(range(1,101), n)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = rnd.sample(range(2,201), n)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = rnd.sample(range(1, 101), n)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

for j in range(Nexamples):
    list1 = rnd.sample(range(2, 201), n)
    X.append(np.array(list1))
    max_ = max(list1)
    y.append(np.array(max_))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.959
#                                                      X    y  y_pred
# 0              [63, 22, 54, 10, 55, 26, 83, 58, 60, 2]   83      92
# 1             [63, 86, 51, 55, 65, 37, 24, 71, 39, 18]   86      80
# 2                [40, 11, 95, 5, 26, 7, 10, 3, 38, 27]   95      97
# 3              [66, 36, 17, 1, 81, 55, 14, 42, 65, 47]   81      80
# 4              [55, 60, 82, 25, 96, 7, 53, 98, 50, 10]   98      95
# ...                                                ...  ...     ...
# 19995  [120, 116, 123, 151, 65, 56, 145, 101, 200, 54]  200     178
# 19996       [27, 44, 79, 22, 35, 155, 58, 11, 161, 46]  161     155
# 19997     [52, 101, 193, 199, 98, 60, 45, 75, 48, 141]  199     188
# 19998   [61, 135, 54, 160, 115, 124, 35, 28, 177, 108]  177     157
# 19999     [149, 73, 128, 200, 96, 161, 11, 170, 2, 94]  200     188
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_4 <= 100.50
# |   |--- feature_5 <= 100.50
# |   |   |--- feature_6 <= 100.50
# |   |   |   |--- feature_8 <= 100.50
# |   |   |   |   |--- feature_9 <= 101.50
# |   |   |   |   |   |--- feature_0 <= 100.50
# |   |   |   |   |   |   |--- feature_7 <= 105.00
# |   |   |   |   |   |   |   |--- feature_1 <= 86.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 86.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 86.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  89.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [96.57]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  86.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [95.25]
# |   |   |   |   |   |   |   |   |--- feature_5 >  86.50
# |   |   |   |   |   |   |   |   |   |--- value: [96.16]
# ...

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()
